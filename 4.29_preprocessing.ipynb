# %%
# =========================
# 0. 环境与路径配置
# =========================
from pathlib import Path

# ——★ 根据自己文件实际位置修改 ★——
DATA_DIR  = Path('.')                       # 元数据所在目录
GCTX_FILE = DATA_DIR / 'level5_beta_trt_cp_n720216x12328.gctx'
INSTINFO  = DATA_DIR / 'instinfo_beta.txt'
COMPOUND  = DATA_DIR / 'compoundinfo_beta.txt'
GENEINFO  = DATA_DIR / 'geneinfo_beta.txt'

# ——★ 16 GB 机器推荐参数 ★——
CHUNK_SIZE  = 2_000        # 每批读取列数
DTYPE_EXPR  = 'float32'    # 累加矩阵精度
DTYPE_COUNT = 'uint16'     # 计数矩阵精度
MIN_REPLICA = 1            # ≥3 次重复才保留

print("✔️ 路径与参数已配置")
# Out:
# ✔️ 路径与参数已配置

# %%
# =========================
# 1. 导入依赖
# =========================
import pandas as pd, numpy as np, re, gc, time, math
from tqdm import tqdm               # 进度条
from cmapPy.pandasGEXpress import parse

print("pandas 版本:", pd.__version__)
# Out:
# pandas 版本: 2.2.3

# %%
# =========================
# 2. plate:well → pert_id   /  pid → SMILES   /  trt_cp 集合
# =========================
def clean_plate(p: str | float) -> str | None:
    """
    仅保留板主名   AICHI001_BJAB_24H
    ----------------------------------------------------------
    去掉尾部所有批次标记（顺序可变，是否存在亦可变）：
      • _X1 / _X2 …              ← 重复编号
      • _F1B10 / _F3B7 …         ← 子板块
      • _DUO52HI53LO …           ← 双孔检测标签
    """
    if not isinstance(p, str):
        return None
    return re.sub(r'(_X\d+)?(_F\d+B\d+)?(_DUO.*)?$', '', p)

print("▶ 读取 instinfo …")
use_cols = ['det_plate', 'det_well', 'rna_plate', 'rna_well',
            'sample_id', 'pert_id', 'pert_type']
inst = pd.read_csv(INSTINFO, sep='\t', usecols=use_cols)

# --- plate:well → pert_id ---
pairs = []
for pc, wc in (('det_plate', 'det_well'),
               ('rna_plate', 'rna_well')):
    tmp = inst[[pc, wc, 'pert_id']].dropna()
    tmp.columns = ['plate', 'well', 'pid']
    pairs += tmp.itertuples(index=False)

sid = inst[['sample_id', 'pert_id']].dropna()
pairs += zip(sid.sample_id.str.split(':').str[0],
             sid.sample_id.str.split(':').str[1],
             sid.pert_id)

plate2pid = {}
for plate, well, pid in pairs:
    key = f"{clean_plate(plate)}:{well}"
    if key not in plate2pid:          # 首次出现即记录
        plate2pid[key] = pid
print(f"plate:well 键数 = {len(plate2pid):,}")

# --- 小分子 trt_cp 集合 ---
trt_cp_set = set(inst.loc[inst.pert_type == 'trt_cp', 'pert_id'])
print("trt_cp pert_id 数 =", len(trt_cp_set))

# --- pert_id → canonical SMILES ---
pid2smi = (pd.read_csv(COMPOUND, sep='\t',
                       usecols=['pert_id', 'canonical_smiles'])
             .set_index('pert_id')['canonical_smiles']
             .dropna()
             .to_dict())
print("含 SMILES 的化合物 =", len(pid2smi))
# Out:
# ▶ 读取 instinfo …
# plate:well 键数 = 3,920,132
# trt_cp pert_id 数 = 34419
# 含 SMILES 的化合物 = 28634

# %%
# =========================
# 3. 读取 geneinfo
# =========================
genes = pd.read_csv(GENEINFO, sep='\t')
n_gene = len(genes)
landmark_mask = genes['feature_space'] == 'landmark'
print(f"基因总数 {n_gene}，其中 landmark = {landmark_mask.sum()}")
# Out:
# 基因总数 12328，其中 landmark = 978

# %%
# =========================
# 4. Pass-1  扫描 cid → SMILES
# =========================
print("▶ 读取 GCTX 列元数据 (col_meta_only=True)…")
meta = parse.parse(str(GCTX_FILE), col_meta_only=True)
cid_all = (meta.index.tolist()
           if isinstance(meta, pd.DataFrame)
           else meta.col_metadata_df.index.tolist())
print("列总数 =", len(cid_all))

cid2sidx = {}           # cid → SMILES 索引
smiles2idx, smiles_list = {}, []
unmatched = 0

for cid in tqdm(cid_all, desc="scan", unit="cid"):
    parts = cid.split(':')
    if len(parts) - 1 >= 2:        # 2/3-colon
        pid = parts[1]
    elif len(parts) - 1 == 1:      # 1-colon
        pid = plate2pid.get(cid)
    else:
        pid = None

    if pid and pid in trt_cp_set and pid in pid2smi:
        smi = pid2smi[pid]
        if smi not in smiles2idx:
            smiles2idx[smi] = len(smiles_list)
            smiles_list.append(smi)
        cid2sidx[cid] = smiles2idx[smi]
    else:
        unmatched += 1

print(f"可用 SMILES 数           = {len(smiles_list):,}")
print(f"可用列 (trt_cp + SMILES) = {len(cid2sidx):,}")
print(f"未用列                    = {unmatched:,}")
# Out:
# ▶ 读取 GCTX 列元数据 (col_meta_only=True)…
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# 列总数 = 720216
# scan: 100%|██████████| 720216/720216 [00:01<00:00, 492176.45cid/s]
# 可用 SMILES 数           = 10,670
# 可用列 (trt_cp + SMILES) = 465,354
# 未用列                    = 254,862

# %%
# =========================
# 5. 初始化 memmap 缓冲
# =========================
n_smiles = len(smiles_list)
expr_sum = np.memmap('expr_sum.dat', dtype=DTYPE_EXPR, mode='w+',
                     shape=(n_gene, n_smiles))
expr_cnt = np.memmap('expr_cnt.dat', dtype=DTYPE_COUNT, mode='w+',
                     shape=(n_gene, n_smiles))
print(f"memmap 创建成功  | genes × SMILES = {expr_sum.shape}")
# Out:
# memmap 创建成功  | genes × SMILES = (12328, 10670)

# %%
# =========================
# 6. Pass-2  分块读取表达矩阵并累加
# =========================
def cid_chunks(seq, size):
    """简单的 list 分块生成器"""
    for i in range(0, len(seq), size):
        yield seq[i:i + size]

start = time.time()
for chunk in tqdm(list(cid_chunks(list(cid2sidx.keys()), CHUNK_SIZE)),
                  desc="accumulate", unit="chunk"):
    gct = parse.parse(str(GCTX_FILE), cid=chunk)
    block = gct.data_df.values.astype(DTYPE_EXPR)    # (genes × chunk)
    idxs  = [cid2sidx[c] for c in chunk]

    for j, s_idx in enumerate(idxs):
        expr_sum[:, s_idx] += block[:, j]
        expr_cnt[:, s_idx] += 1

    del gct, block
    gc.collect()

print("累加完成，耗时 %.1f 分钟" % ((time.time() - start) / 60))
# Out:
# accumulate:   0%|          | 0/233 [00:00<?, ?chunk/s]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   0%|          | 1/233 [00:10<40:20, 10.43s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   1%|          | 2/233 [00:15<27:11,  7.06s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   1%|▏         | 3/233 [00:20<23:25,  6.11s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   2%|▏         | 4/233 [00:25<21:53,  5.74s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   2%|▏         | 5/233 [00:30<20:28,  5.39s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   3%|▎         | 6/233 [00:34<19:22,  5.12s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   3%|▎         | 7/233 [00:39<18:25,  4.89s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   3%|▎         | 8/233 [00:43<17:44,  4.73s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   4%|▍         | 9/233 [00:47<17:15,  4.62s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   4%|▍         | 10/233 [00:52<16:54,  4.55s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   5%|▍         | 11/233 [00:56<16:35,  4.49s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:
/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  29%|██▉       | 68/233 [29:56<15:28,  5.63s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  30%|██▉       | 69/233 [30:01<14:44,  5.39s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# ...
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  90%|█████████ | 210/233 [42:10<01:31,  3.96s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  91%|█████████ | 211/233 [42:15<01:37,  4.42s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  91%|█████████ | 212/233 [42:21<01:38,  4.70s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  91%|█████████▏| 213/233 [42:26<01:40,  5.01s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  92%|█████████▏| 214/233 [42:32<01:39,  5.26s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  92%|█████████▏| 215/233 [42:38<01:36,  5.36s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  93%|█████████▎| 216/233 [42:43<01:31,  5.40s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  93%|█████████▎| 217/233 [42:49<01:27,  5.44s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  94%|█████████▎| 218/233 [42:55<01:22,  5.49s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  94%|█████████▍| 219/233 [43:00<01:16,  5.49s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  94%|█████████▍| 220/233 [43:06<01:11,  5.51s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  95%|█████████▍| 221/233 [43:11<01:06,  5.51s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  95%|█████████▌| 222/233 [43:17<01:00,  5.54s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  96%|█████████▌| 223/233 [43:22<00:54,  5.42s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  96%|█████████▌| 224/233 [43:27<00:48,  5.35s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  97%|█████████▋| 225/233 [43:32<00:42,  5.28s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  97%|█████████▋| 226/233 [43:37<00:36,  5.26s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  97%|█████████▋| 227/233 [43:42<00:31,  5.22s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  98%|█████████▊| 228/233 [43:48<00:25,  5.20s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  98%|█████████▊| 229/233 [43:53<00:20,  5.17s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  99%|█████████▊| 230/233 [43:58<00:15,  5.15s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  99%|█████████▉| 231/233 [44:03<00:10,  5.13s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate: 100%|█████████▉| 232/233 [44:08<00:05,  5.10s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate: 100%|██████████| 233/233 [44:13<00:00, 11.39s/chunk]
# 累加完成，耗时 44.2 分钟

# %%
# =========================
# 6. Pass-2  分块读取表达矩阵并累加
# =========================
def cid_chunks(seq, size):
    """简单的 list 分块生成器"""
    for i in range(0, len(seq), size):
        yield seq[i:i + size]

start = time.time()
for chunk in tqdm(list(cid_chunks(list(cid2sidx.keys()), CHUNK_SIZE)),
                  desc="accumulate", unit="chunk"):
    gct = parse.parse(str(GCTX_FILE), cid=chunk)
    block = gct.data_df.values.astype(DTYPE_EXPR)    # (genes × chunk)
    idxs  = [cid2sidx[c] for c in chunk]

    for j, s_idx in enumerate(idxs):
        expr_sum[:, s_idx] += block[:, j]
        expr_cnt[:, s_idx] += 1

    del gct, block
    gc.collect()

print("累加完成，耗时 %.1f 分钟" % ((time.time() - start) / 60))
# Out:
# accumulate:   0%|          | 0/233 [00:00<?, ?chunk/s]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   0%|          | 1/233 [00:05<21:32,  5.57s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   1%|          | 2/233 [00:10<20:21,  5.29s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   1%|▏         | 3/233 [00:16<20:30,  5.35s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   2%|▏         | 4/233 [00:21<20:44,  5.43s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   2%|▏         | 5/233 [00:26<20:19,  5.35s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   3%|▎         | 6/233 [00:31<19:42,  5.21s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   3%|▎         | 7/233 [00:36<19:10,  5.09s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   3%|▎         | 8/233 [00:41<18:48,  5.01s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   4%|▍         | 9/233 [00:46<18:30,  4.96s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   4%|▍         | 10/233 [00:51<18:18,  4.93s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   5%|▍         | 11/233 [00:55<18:06,  4.89s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   5%|▌         | 12/233 [01:00<17:52,  4.85s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   6%|▌         | 13/233 [01:05<17:43,  4.83s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   6%|▌         | 14/233 [01:10<17:39,  4.84s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   6%|▋         | 15/233 [01:15<17:36,  4.85s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:   7%|▋         | 16/233 [01:20<17:35,  4.86s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:
/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  92%|█████████▏| 214/233 [18:07<01:36,  5.06s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  92%|█████████▏| 215/233 [18:12<01:30,  5.05s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  93%|█████████▎| 216/233 [18:17<01:25,  5.04s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  93%|█████████▎| 217/233 [18:22<01:20,  5.05s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  94%|█████████▎| 218/233 [18:27<01:15,  5.05s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  94%|█████████▍| 219/233 [18:32<01:10,  5.05s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  94%|█████████▍| 220/233 [18:37<01:05,  5.06s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  95%|█████████▍| 221/233 [18:42<01:00,  5.06s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  95%|█████████▌| 222/233 [18:47<00:55,  5.06s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  96%|█████████▌| 223/233 [18:52<00:50,  5.06s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  96%|█████████▌| 224/233 [18:57<00:45,  5.06s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  97%|█████████▋| 225/233 [19:02<00:40,  5.06s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  97%|█████████▋| 226/233 [19:07<00:35,  5.05s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  97%|█████████▋| 227/233 [19:12<00:30,  5.05s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  98%|█████████▊| 228/233 [19:17<00:25,  5.04s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  98%|█████████▊| 229/233 [19:22<00:20,  5.03s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  99%|█████████▊| 230/233 [19:27<00:15,  5.00s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate:  99%|█████████▉| 231/233 [19:32<00:10,  5.00s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate: 100%|█████████▉| 232/233 [19:37<00:04,  5.00s/chunk]e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# e:\conda\envs\L000\Lib\site-packages\cmapPy\pandasGEXpress\parse_gctx.py:275: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   meta_df = meta_df.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# accumulate: 100%|██████████| 233/233 [19:42<00:00,  5.08s/chunk]
# 累加完成，耗时 19.7 分钟

# %%
# =========================
# 7. 计算均值并过滤
# =========================
valid = expr_cnt >= MIN_REPLICA
keep_mask = valid.any(axis=0)          # 至少有一个基因满足
print("满足重复 ≥1 的 SMILES =", keep_mask.sum())

expr_mean = np.divide(expr_sum[:, keep_mask],
                      expr_cnt[:, keep_mask],
                      where=expr_cnt[:, keep_mask] != 0,
                      out=np.full_like(expr_sum[:, keep_mask], np.nan))
final_smiles = [s for s, flag in zip(smiles_list, keep_mask) if flag]
# Out:
# 满足重复 ≥3 的 SMILES = 10670

# %%
# =========================
# 8. 导出 12328 基因 × SMILES
# =========================
out12328 = 'expr_by_smiles_12328.csv'
print("▶ 写出", out12328)
with open(out12328, 'w', newline='') as f:
    header = ['gene_id', 'gene_symbol', 'feature_space', *final_smiles]
    f.write(','.join(header) + '\n')
    for i, row in enumerate(expr_mean):
        rec = [str(genes.at[i, 'gene_id']),
               genes.at[i, 'gene_symbol'],
               genes.at[i, 'feature_space'],
               *[f"{x:.4f}" if not math.isnan(x) else '' for x in row]]
        f.write(','.join(rec) + '\n')
print("✅ 12328 文件完成")
# Out:
# ▶ 写出 expr_by_smiles_12328.csv
# ✅ 12328 文件完成

# %%
# =========================
# 9. 导出 978 Landmark 基因 × SMILES
# =========================
out978 = 'expr_by_smiles_978.csv'
print("▶ 写出", out978)
with open(out978, 'w', newline='') as f:
    header = ['gene_id', 'gene_symbol', 'feature_space', *final_smiles]
    f.write(','.join(header) + '\n')
    for i, row in zip(np.where(landmark_mask)[0], expr_mean[landmark_mask]):
        rec = [str(genes.at[i, 'gene_id']),
               genes.at[i, 'gene_symbol'],
               genes.at[i, 'feature_space'],
               *[f"{x:.4f}" if not math.isnan(x) else '' for x in row]]
        f.write(','.join(rec) + '\n')
print("✅ 978 文件完成")
# Out:
# ▶ 写出 expr_by_smiles_978.csv
# ✅ 978 文件完成
